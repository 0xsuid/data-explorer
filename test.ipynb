# %%
import pandas as pd

# %%
dataset = pd.read_csv("./seeder/TestData.csv", encoding='cp1252')
dataset
# Out:
#                              internalUUID                            flowName  \
# 0    3978562e-a1e7-4ace-a199-031576d88e14             1,1'-methylenedibenzene
# 1    1ce095a6-8063-4d16-b130-1855a410aa89             1,1'-methylenedibenzene
# 2    1f71e0f6-af05-4dc0-9d91-2a4f54797568             1,1'-methylenedibenzene
# 3    fa1c3f69-1242-42be-9bbf-ef2f9e7848b9             1,1'-methylenedibenzene
# 4    efc73600-27c5-470d-96cf-cfe553d26f76             1,1'-methylenedibenzene
# ..                                    ...                                 ...
# 237  1ac50ab7-9160-4f12-bfdd-aea47995ce6a  1,8-Diazabicyclo(5.4.0)undec-7-ene
# 238  6c6adab9-8c4c-4fe2-b156-ceeca8b147c7  1,8-Diazabicyclo(5.4.0)undec-7-ene
# 239  928a3318-fbad-4e58-8bb0-983f3bac9b62  1,8-Diazabicyclo(5.4.0)undec-7-ene
# 240  febdb6c3-2293-4a88-8f08-462e21edf001  1,8-Diazabicyclo(5.4.0)undec-7-ene
# 241  61ffb0ad-a3bb-4dac-b4a7-6ffbc2672fbd  1,8-Diazabicyclo(5.4.0)undec-7-ene
#
# ...

# %%
dataset["flowName"].unique()
# Out:
# array(["1,1'-methylenedibenzene", '1,2,3-trichlorobenzene',
#        '1,2-diaminopropane', '1,3-dichloropropene',
#        '1,8-Diazabicyclo(5.4.0)undec-7-ene'], dtype=object)

# %%
dataset["processName"].unique()
# Out:
# array(['friedel-craft alkylation', 'reaction of benzene and chlorine',
#        'reaction of propylene dichloride and ammonia',
#        'dehydration of 1,3-dichloro-2-propanol',
#        'reaction of 1,3-propanediamine and adipaldehyde'], dtype=object)

# %%
dataset["country"].unique()
# Out:
# array(['Algeria', 'Argentina', 'Austria', 'Belarus', 'Belgium', 'Brazil',
#        'Brunei Darussalam', 'Canada', 'China', 'Colombia', 'Czechia',
#        'Egypt', 'Finland', 'France', 'Germany', 'Hungary', 'India',
#        'Indonesia', 'Iran', 'Israel', 'Italy', 'Japan', 'Kuwait',
#        'Latvia', 'Malaysia', 'Mexico', 'Netherlands', 'Nigeria', 'Oman',
#        'Philippines', 'Poland', 'Portugal', 'Qatar', 'Republic of Korea',
#        'Romania', 'Russia', 'Saudi Arabia', 'Serbia and Montenegro',
#        'Singapore', 'Slovakia', 'Spain', 'Switzerland',
#        'Taiwan, Province of China', 'Thailand', 'Turkey', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'United States',
#        'Uzbekistan', 'Venezuela', 'Viet Nam', 'Global',
#        'EU-27 Member States', 'Rest-of-World',
#        'Europe, Middle East, Africa', 'South Asia Pacific',
#        'Northwest Europe', 'Eastern Asia',
#        'Latin America and the Caribbean', 'Northern America',
# ...

# %%
dataset["ISOTwoLetterCountryCode"].unique()
# Out:
# array(['DZ', 'AR', 'AT', 'BY', 'BE', 'BR', 'BN', 'CA', 'CN', 'CO', 'CZ',
#        'EG', 'FI', 'FR', 'DE', 'HU', 'IN', 'ID', 'IR', 'IL', 'IT', 'JP',
#        'KW', 'LV', 'MY', 'MX', 'NL', 'NG', 'OM', 'PH', 'PL', 'PT', 'QA',
#        'KR', 'RO', 'RU', 'SA', 'CS', 'SG', 'SK', 'ES', 'CH', 'TW', 'TH',
#        'TR', 'UA', 'AE', 'GB', 'US', 'UZ', 'VE', 'VN', 'GLO', 'EU-27',
#        'RoW', 'EMEA', 'SAPAC', 'NWE', 'UN-EASIA', 'RLA', 'RNA',
#        'UN-WASIA', 'KP', 'AU', 'IE', 'PK', 'SE', 'BG', 'HR', 'GR', 'MA'],
#       dtype=object)

# %%
dataset.columns
# Out:
# Index(['internalUUID', 'flowName', 'type', 'CAS', 'processName', 'country',
#        'ISOTwoLetterCountryCode', 'processDescription', 'bioCarbonContent',
#        'carbonContent', 'allocationType', 'declaredUnit', 'referencePeriod',
#        'TechRep', 'TimeRep', 'GeoRep', 'Completeness', 'Reliability',
#        'MethodConsistency', 'OverallQuality', 'TechRep_TfS', 'TimeRep_TfS',
#        'GeoRep_TfS', 'Completeness_TfS', 'Reliability_TfS',
#        'OverallQuality_TfS', 'DQRShort_TfS', 'PDS_TfS',
#        'Carbon Minds ISO 14067 (based on IPCC 2021) - climate change - global warming potential (GWP100) [kg CO2-Eq]',
#        'Carbon Minds ISO 14067 (based on IPCC 2021) - climate change: biogenic emissions - global warming potential (GWP100) [kg CO2-Eq]',
#        'Carbon Minds ISO 14067 (based on IPCC 2021) - climate change: biogenic removal - global warming potential (GWP100) [kg CO2-Eq]',
# ...

# %%
dataset["TechRep_TfS"].unique()
# Out:
# array(['3 | Poor | The main product under study is modeled using an industrially relevant production technology that is not necessarily the market’s dominant technology. Raw materials are partly based on consumption mixes, the market’s dominant production technology, or an industrially relevant production technology. The production of crude oil, naphtha, and natural gas is represented by data for production and consumption mixes from Ecoinvent (e.g., a specific European country or European average).'],
#       dtype=object)

# %%
dataset["GeoRep_TfS"].unique()
# Out:
# array(['1 | Good | Simplified technical process data (e.g., mass and energy balances) is used for each industrially relevant production technology. Part of the raw materials is based on national consumption mixes, the market’s dominant production technology, or an industrially relevant production technology. Country-specific fossil feedstock supplies are applied whenever possible. Otherwise, larger regional averages are used. Fossil feedstock, energy, and electricity supplies are modeled based on data from the Ecoinvent database using the cut-off system model. Trade balances are only included for some raw materials.'],
#       dtype=object)

# %%
"3 | Poor | The main product".split("|")[0]
# Out:
# '3 '
